# %% [markdown]
# <a href="https://colab.research.google.com/github/DevsashreeMankar/AD/blob/main/Project_Customer_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('/content/customers.csv')

# %%
df2 = pd.read_csv('/content/products.csv')

# %%
df3 = pd.read_csv('/content/transactions.csv')

# %%
df1.head(5)
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive       createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y   9/21/2017 12:38
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y    5/22/2017 5:29
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y  09-03-2017 12:11
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y    2/16/2017 4:05
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y    5/15/2017 7:34
#
#         updatedDate
# 0  10/18/2017 12:12
# 1  10/18/2017 12:12
# 2  10/18/2017 12:12
# 3  10/18/2017 12:12
# 4  10/18/2017 12:12

# %%
df2.head(5)
# Out:
#    productno productName Description isActive       createdDate  \
# 0          1    Product1  pgqorighfa        Y  03-04-2017 07:58
# 1          2    Product2  lmndaaweth        Y  21-09-2017 12:38
# 2          3    Product3  urifeubrhh        Y  08-09-2017 10:32
# 3          4    Product4  rlpcjxfarp        Y  22-05-2017 05:29
# 4          5    Product5  hzcpozsgfc        Y  02-02-2017 08:40
#
#         UpdatedDate
# 0  18-10-2017 12:12
# 1  18-10-2017 12:12
# 2  18-10-2017 12:12
# 3  18-10-2017 12:12
# 4  18-10-2017 12:12

# %%
df3.head(5)
# Out:
#    txnno           txndate  custno  amount  productno spendby
# 0      1  18-10-2017 12:31     923    2559        376    Card
# 1      2  18-10-2017 12:31     219    1706        151    Card
# 2      3  18-10-2017 12:31     927    3462        707    Cash
# 3      4  18-10-2017 12:31     806     865        539    Card
# 4      5  18-10-2017 12:31     958    2494         25    Card

# %%
#4 Display top 5 transactions amount from CSV_s1
df3.head(5)['amount']
# Out:
# 0    2559
# 1    1706
# 2    3462
# 3     865
# 4    2494
# Name: amount, dtype: int64

# %%
cst1 = df1[df1['custno']==923][['custno','gender','age','profession','contactNo']]
cst1[['custno','gender','age','profession','contactNo']]
# Out:
#      custno gender  age profession  contactNo
# 922     923      F   46          B      25436

# %%
cst2 = df3[df3['custno']==923][['txndate','amount','spendby']]
cst2[['txndate','amount','spendby']]
# Out:
#               txndate  amount spendby
# 0    18-10-2017 12:31    2559    Card
# 334  18-10-2017 12:31    2303    Card
# 932  18-10-2017 12:31    4553    Cash

# %%
pd.concat([cst1,cst2])
# Out:
#      custno firstname lastname gender   age profession  contactNo  \
# 922     923   Russell  Walters      F  46.0          B    25436.0
# 0       923       NaN      NaN    NaN   NaN        NaN        NaN
# 334     923       NaN      NaN    NaN   NaN        NaN        NaN
# 932     923       NaN      NaN    NaN   NaN        NaN        NaN
#
#                  emailId      city  state isActive     createdDate  \
# 922  esears55@ma1lbox.us  Cuthbert  Odell        Y  7/30/2017 1:30
# 0                    NaN       NaN    NaN      NaN             NaN
# 334                  NaN       NaN    NaN      NaN             NaN
# 932                  NaN       NaN    NaN      NaN             NaN
#
#           updatedDate  txnno           txndate  amount  productno spendby
# 922  10/18/2017 12:12    NaN               NaN     NaN        NaN     NaN
# 0                 NaN    1.0  18-10-2017 12:31  2559.0      376.0    Card
# 334               NaN  335.0  18-10-2017 12:31  2303.0      113.0    Card
# ...

# %%
#Display distinct professions from CSV_s1
df1['profession'].unique()
# Out:
# array(['B', 'S'], dtype=object)

# %%
cst4 = df3[df3['custno']==923][['txndate','amount','spendby']]
cst4
# Out:
#               txndate  amount spendby
# 0    18-10-2017 12:31    2559    Card
# 334  18-10-2017 12:31    2303    Card
# 932  18-10-2017 12:31    4553    Cash

# %%
cst3 = df1[df1['custno']==923][['custno','gender','age','profession','contactNo']]

# %%
pd.concat((cst3,cst4))
# Out:
#      custno gender   age profession  contactNo           txndate  amount  \
# 922   923.0      F  46.0          B    25436.0               NaN     NaN
# 0       NaN    NaN   NaN        NaN        NaN  18-10-2017 12:31  2559.0
# 334     NaN    NaN   NaN        NaN        NaN  18-10-2017 12:31  2303.0
# 932     NaN    NaN   NaN        NaN        NaN  18-10-2017 12:31  4553.0
#
#     spendby
# 922     NaN
# 0      Card
# 334    Card
# 932    Cash

# %%
#Display highest age in CSV_s1 customer’s dataset
df1['age'].max()
# Out:
# 64

# %%
#Display top 5 most demanded products from CSV_s1
dprod = df3['productno'].value_counts().head(5)

# %%
dprod
# Out:
# 82     5
# 427    5
# 900    5
# 768    5
# 849    4
# Name: productno, dtype: int64

# %%
# Display only those customers from CSV_s1, who purchased more than 3 product
cust_prod = df1[df1['custno'].isin(df3['custno'].value_counts()[df3['custno'].value_counts() > 3].index)]

# %%
cust_prod
# Out:
#      custno  firstname  lastname gender  age profession  contactNo  \
# 3         4     Alexis    Battle      M   27          S      71701
# 85       86     Bonnie    McCall      M   37          S      70907
# 166     167      Alice     Blake      F   58          B      22324
# 186     187       Alan   Anthony      F   50          B      40487
# 236     237       Dawn      West      F   26          B      75618
# 240     241    Derrick   Pearson      F   33          B      74138
# 320     321    Crystal        Le      F   64          B      37857
# 325     326      Heidi   Stanley      M   29          S      78822
# 330     331    Cynthia  Harrison      F   49          B      53439
# 355     356   Mitchell     Mason      M   37          S      45064
# 390     391      Keith    Church      F   19          B      26859
# 536     537       Jake      Bush      F   23          B      80535
# 557     558       Lois      Todd      M   58          S      39051
# ...
